# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import importlib

# %%
import model_utils
importlib.reload(model_utils)
# Out:
# <module 'model_utils' from '/Users/fjdu/Dropbox/myCodes/DeuterationGasGrain/jupyter/model_utils.py'>

# %%
model_utils.write_initial_condition('init.dat', d_ini)

# %%
d2g = model_utils.dust2gas(r_dust_micron=1)
Nsites = model_utils.getNSites(r_dust_micron=1)
d_ini = model_utils.make_initial_condition_CO_H2O_ice(d2g, Nsites)

# %%
(model_utils.dust2gas(r_dust_micron=1),
 model_utils.getMonolayers(1e11, r_dust_micron=1),
 model_utils.getNSites(r_dust_micron=1)/1e6)
# Out:
# (2.7907819271163844e-15, 795.7747154594767, 125.66370614359171)

# %%
d = model_utils.load_time_evol_data('../output_2/evolution_moment.dat')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim((1e1,1e6))
ax.set_ylim((1e-14, 1e-3))
ax.grid(axis='both', which='both')

species = ['C2H', 'C3H2', 'mH2O', 'gH2O', 'H2O', 'mCO', 'gCO', 'CO']
for sp in species:
    ax.plot(d['Time_(yr)'], d[sp]*model_utils.dust2gas(r_dust_micron=1), label=sp)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
